# %%
setwd("/Users/rebecca/sudmant/analyses/myotis/analysis/exploratory/presentation_figures")

library(pafr)

paf_dir <- "/Users/rebecca/sudmant/analyses/myotis/data/pafs"

# %%
paf1 <- read_paf(file.path(paf_dir, "mMyoAui1.cleaned.hapheader_mMyoCai1.cleaned.hapheader.exact.paf"), include_tags = FALSE)
paf2 <- read_paf(file.path(paf_dir, "mMyoCai1.cleaned.hapheader_mMyoAui1.cleaned.hapheader.exact.paf"), include_tags = FALSE)

# %%
head(paf1 %>% arrange(qname, qstart))
# Out:
#   qname               qlen      qstart   qend     strand tname
# 1 mMyoCai1.0.SUPER__1 234393516    26288  2856368 -      mMyoAui1.0.SUPER__1
# 2 mMyoCai1.0.SUPER__1 234393516  2911840 43420000 -      mMyoAui1.0.SUPER__1
# 3 mMyoCai1.0.SUPER__1 234393516 43400400 48690000 -      mMyoAui1.0.SUPER__1
# 4 mMyoCai1.0.SUPER__1 234393516 48740000 68004616 -      mMyoAui1.0.SUPER__1
# 5 mMyoCai1.0.SUPER__1 234393516 67991176 88958984 -      mMyoAui1.0.SUPER__1
# 6 mMyoCai1.0.SUPER__1 234393516 88967176 89124232 -      mMyoAui1.0.SUPER__1
#   tlen      tstart    tend      nmatch   alen     mapq
# 1 234041302 231186952 234012568  2452297  2830080 7
# 2 234041302 191040403 231203767 36276291 40508160 8
# 3 234041302 185945380 191138601  4630968  5289600 7
# 4 234041302 166989503 185944909 16961205 19264616 7
# 5 234041302 146113880 166958530 18568478 20967808 7
# 6 234041302 144985499 145168687   136315   183188 5

# %%
head(paf2 %>% arrange(tname, tstart))
# Out:
#   qname               qlen      qstart    qend      strand tname
# 1 mMyoAui1.0.SUPER__1 234041302 231190000 234005000 -      mMyoCai1.0.SUPER__1
# 2 mMyoAui1.0.SUPER__1 234041302 191075000 231190000 -      mMyoCai1.0.SUPER__1
# 3 mMyoAui1.0.SUPER__1 234041302 146113928 191116808 -      mMyoCai1.0.SUPER__1
# 4 mMyoAui1.0.SUPER__1 234041302 145825000 145872440 -      mMyoCai1.0.SUPER__1
# 5 mMyoAui1.0.SUPER__1 234041302 145371248 145428976 -      mMyoCai1.0.SUPER__1
# 6 mMyoAui1.0.SUPER__1 234041302 145910000 146055000 -      mMyoCai1.0.SUPER__1
#   tlen      tstart   tend     nmatch   alen     mapq
# 1 234393516    40357  2853349  2447338  2815000 7
# 2 234393516  2964463 43397795 36221675 40433332 8
# 3 234393516 43421219 88958936 40109649 45537717 7
# 4 234393516 88913305 88960312    41919    47440 7
# 5 234393516 88913313 88966107    45578    57728 6
# 6 234393516 89150151 89298900   127709   148749 7

# %%
plot_synteny(paf1[2,], q_chrom="mMyoCai1.0.SUPER__1", t_chrom="mMyoAui1.0.SUPER__1", centre=FALSE) +
    theme_bw()
# Out:
# plot without title

# %%
plot_synteny(paf2[2,], t_chrom="mMyoCai1.0.SUPER__1", q_chrom="mMyoAui1.0.SUPER__1", centre=FALSE) +
    theme_bw()
# Out:
# plot without title
