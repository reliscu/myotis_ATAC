# %%
library(data.table)

# %%
peaks_genes <- fread("/Users/rebecca/sudmant/analyses/myotis/data/ATAC-seq/genes/Myotis-Auriculus/Consensus_Peaks_Annotations_Accross_All_Samples.csv", data.table = FALSE)
hist(peaks_genes$`Distance to TSS`, breaks=100)
summary(peaks_genes$`Distance to TSS`)
# Out:
#     Min.  1st Qu.   Median     Mean  3rd Qu.     Max.     NA's
# -1561741   -15972     5004    10690    37192  2180491      470
# Plot with title "Histogram of peaks_genes$`Distance to TSS`"

# %%
peaks_TEs <- fread("/Users/rebecca/sudmant/analyses/myotis/data/ATAC-seq/TEs/Myotis-Auriculus/Consensus_Peaks_Annotations_Accross_All_Samples.csv", data.table = FALSE)
hist(peaks_TEs$`Distance to TSS`, breaks=100)
summary(peaks_TEs$`Distance to TSS`)
# Out:
#     Min.  1st Qu.   Median     Mean  3rd Qu.     Max.     NA's
# -1552014   -30272     -350    -2032    28379  1549325       10
# Plot with title "Histogram of peaks_TEs$`Distance to TSS`"

# %%
peaks_genes <- fread("/Users/rebecca/sudmant/analyses/myotis/data/ATAC-seq/genes/Myotis-Thysanodes/Consensus_Peaks_Annotations_Accross_All_Samples.csv", data.table = FALSE)
hist(peaks_genes$`Distance to TSS`, breaks=100)
summary(peaks_genes$`Distance to TSS`)
# Out:
#     Min.  1st Qu.   Median     Mean  3rd Qu.     Max.     NA's
# -2142555   -18264     5142    10626    39208  1419169      464
# Plot with title "Histogram of peaks_genes$`Distance to TSS`"
