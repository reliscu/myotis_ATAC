# %%
library(data.table)
dat <- fread("../../../data/ATAC-seq/genes/Myotis-Auriculus/Consensus_Peaks_Annotations_Accross_All_Samples.tsv", data.table = FALSE)
hist(dat$`Distance to TSS`, breaks=100)

# %%
# Out:
# Plot with title "Histogram of dat$`Distance to TSS`"

# %%
summary(dat$`Distance to TSS`)
# Out:
#     Min.  1st Qu.   Median     Mean  3rd Qu.     Max.     NA's
# -1561741   -15972     5004    10690    37192  2180491      470
